# %% [markdown]
# <a href="https://colab.research.google.com/github/ghimirebabin07/Python_Learning-/blob/master/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating my first
class student :
  name = "babin"
  age = 20
s1 = student
print(s1.name)
# Out:
# babin

# %%
#the __init__()
class Student:
  def __init__(self, name, age):#self means the current object itself
    self.name = name
    self.age = age
s1 = Student("Babin",20)
s2 = Student("Bishnu",52)
print(s1.name, s2.age)
print(s2.name, s1.age)
# Out:
# Babin 52
# Bishnu 20

# %%
#methods in the class
class student:
  def __init__(self,name):
    self.name = name
  def methodma(self): #making the methods like function
    print("Hello",self.name)
s1 = student("Babin")
s1.methodma()
# Out:
# Hello Babin

# %%
#challenge 1
class book :
  def __init__(self, title, author, price):
    self.title = title
    self.author = author
    self.price = price
  def displaybook(self):
    print("Title:\n",self.title,"Author Name:", self.author,"\nPrice:\n",self.price)
b = book(input("Enter the title:"),input("Enter the author:"),int(input("Enter the price")))
b.displaybook()
# Out:
# Enter the title:amtoic habtis
# Enter the author:jems
# Enter the price1200
# Title:
#  amtoic habtis
# Author Name:
#  jems
# Price:
#  1200

# %%
#challenge 2
class mobile:
  def __init__(self,brand,model,battery):
    self.brand = brand
    self.model = model
    self.battery = battery
  def show_details(self):
    print("Brand:\n",self.brand,"\nModel:\n",self.model,"\nBattery:\n",self.battery)
  def charge(self):
    if self.battery == 100:
        print ("The battery is full ")
    else:
      self.battery = 100
      print("Mobile is fully charged")
phone = mobile("Samsung","Galaxy s26",85)
print("\nBefore Charging:")
phone.show_details()

print("\nCharging Status:")
phone.charge()

print("\nAfter Charging:")
phone.show_details()
# Out:
# Before Charging:
# Brand:
#  Samsung
# Model:
#  Galaxy s26
# Battery:
#  85
#
# Charging Status:
# Mobile is fully charged
#
# After Charging:
# Brand:
#  Samsung
# Model:
#  Galaxy s26
# Battery:
#  100

# %%
#challenge 3
class student:
  def __init__(self,name,marks):
    self.name = name
    self.marks = marks
  def grade(self):
   if self.marks >=90:
    print("Grade A")
   elif self.marks >=80:
    print("Grade B")
   elif self.marks >=70:
    print("Grade C")
   elif self.marks >=60:
    print("Grade D")
   else:
    print("Grade NG")
s = student("Babin",34)
s.grade()
# Out:
# Grade NG

# %%
#challenge 4
class rectangle:
  def __init__(self,length,breadth):
    self.length = length
    self.breadth = breadth
  def area(self):
    print("Area of the rectangle",self.length*self.breadth)
  def perimeter(self):
    print("Perimeter of the rectangle",2*(self.length+self.breadth))
r = rectangle(2,3)
r.area()
r.perimeter()
# Out:
# Area of the rectangle 6
# Perimeter of the rectangle 10

# %%
#challenge 5
class accountbalance:
  def __init__(self,owner,balance,accountnumber):
    self.owner = owner
    self.balance = balance
    self.accountnumber = accountnumber
  def deposite(self):
    amount = int(input("Enter the amount to deposite:"))
    self.balance += amount
    print("New balance:",self.balance)

  def withdraw(self):
    amount = int(input('Enter the amount to withdraw: '))
    if amount <= self.balance:
      self.balance -= amount
      print(("New balance:",self.balance))
    else:
      print("Insufficient balance!")
ac=accountbalance("Babin",1000,12345)
ac.deposite()
ac.withdraw()
# Out:
# Enter the amount to deposite:3400
# New balance: 4400
# Enter the amount to withdraw: 3000
# ('New balance:', 1400)

# %%
#ATM
class account:
  def __init__(self,owner,balance):
    self.owner = owner
    self.balance = balance

  def deposite(self,amount):
    self.balance +=amount
    print("New balance:",self.balance)

  def withdraw(self,amount):
    if amount <= self.balance:
      self.balance -= amount
      print("New balance :",self.balance)
    else:
      print("Insufficient balance!")

  def checkbalance(self):
    print("Current Balance:",self.balance)

acc = account("Babin",200000)

while True:
  print("\n====ATM Options====")
  print("1.Deposite")
  print("2.Withdraw")
  print("3.Check Balance")
  print("4.Exit")

  choice = input("Enter choice:")
  if choice == "1":
    amt = int(input("Enter the amount"))
    acc.deposite(amt)
  elif choice == "2":
    amt = int(input("Enter the amout :"))
    acc.withdraw(amt)
  elif choice == "3":
    acc.checkbalance()
  elif choice == "4":
    print("thank you for using ATM")
    break
  else:
    print("Invalid choice")
# Out:
# ====ATM Options====
# 1.Deposite
# 2.Withdraw
# 3.Check Balance
# 4.Exit
# Enter choice:2
# Enter the amout :1230
# New balance : 198770
#
# ====ATM Options====
# 1.Deposite
# 2.Withdraw
# 3.Check Balance
# 4.Exit
# Enter choice:4
# thank you for using ATM

# %%
#upgraded in the ATM with security:
class AtmSystem:
  def __init__(self,owner,balance,pin):
    self.owner = owner
    self.balance = balance
    self.pin = pin
    self.history = []
  def deposite(self,amount):
    self.balance +=amount
    self.history.append(f"Deposite: {amount}")
    print("New balance:",self.balance)

  def withdraw(self, amount):
    if amount <= self.balance:
      self.balance -=amount
      self.history.append(f"Withdraw: {amount}")
      print("New balance:",self.balance)
    else:
      print("Insufficient balance!")

  def checkbalance(self):
    print("Current Balance",self.balance)

  def show_history(self):
    print("\n--Transaction History--")
    if not self.history:
      print("No transaction yet")
    else:
      for i in self.history:
        print(i)

acc = AtmSystem("Babin",200,"12345")

attempts = 3

while attempts > 0:
  pint = input("Enter your pin:")

# %%
#inheritance
class BankAccount:
  def __init__(self,owner,balance=0):
    self.owner = owner
    self.balance = balance
  def deposit(self,amount):
    if amount <= 0:
      print("The amount must be positive")
      return
    self.balance +=amount
    print(f"Deposited Rs.{amount}.New balance:Rs.{self.balance}")

  def withdraw(self,amount):
    if amount <=0:
      print("The amount must be positive")
      return
    if amount > self.balance:
      print(f"Insufficient funds. Current balance: Rs.{self.balance}")
      return
    self.balance -= amount
    print(f"Withdraw Rs.{amount}.Remaining Balance:Rs.{self.balance}")

  def get_details(self):
    print(f"Account Owner:{self.owner}")
    print(f"Balance:Rs.{self.balance}")
    print(f"Account type : {type(self.__name__)}")

# %%
#error handling comon errors
print(10/0)
print(int("hello"))
print(open("none.txt"))
print(x+1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_4040/2813575139.py in <cell line: 0>()
#       1 #error handling
# ----> 2 print(10/0)
#       3
#
# ZeroDivisionError: division by zero

# %%
try:
  result = 10/0
except ZeroDivisionError:
  print("Cannot divide by zero !")
# Out:
# Cannot divide by zero !

# %%
def convert(value ):
  try:
    return int(value)
  except ValueError:
    print("That's not a number ")
  except TypeError:
    print("Wrong type passed ")
convert("Hello")
convert(None)
# Out:
# That's not a number
# Wrong type passed

# %%
#else and finally
try:
  number = int(input("Enter a number: "))
except ValueError:
  print(f"Not a valid number :")
else:
  print(f"You Entered :{number}")
finally:
  print(f"This always runs.")
# Out:
# Enter a number: 0
# You Entered :0
# This always runs.

# %%
class InsufficientFundsError(Exception):
    def __init__(self, balance, amount):
        self.message = f"Cannot withdraw Rs. {amount}. Balance is only Rs. {balance}"
        super().__init__(self.message)

def withdraw(balance, amount):
    if amount > balance:
        raise InsufficientFundsError(balance, amount)
    return balance - amount

try:
    withdraw(500, 1000)

except InsufficientFundsError as e:
    print(e)
# Out:
# Cannot withdraw Rs. 1000. Balance is only Rs. 500

# %%
# reading and writing files
with open("notes.txt","w") as f: # w = write
  f.write("Hello, this is my first file.\n")
  f.write("Second line here.")

with open("notes.txt","r") as f : # r = read
    content = f.read()
    print(content)
# Out:
# Hello, this is my first file.
# Second line here.

# %%
with open("notes.txt","r") as f :
  lines = f.readlines()
  for line in lines :
    print(line.strip())
# Out:
# Hello, this is my first file.
# Second line here.

# %%
#a = append mode
with open("notes.txt","a") as f:
  f.write("\n This line was added later.")

with open("notes.txt","r") as f :
  content = f.read()
  print(content)
# Out:
# Hello, this is my first file.
# Second line here.
#  This line was added later.
#  This line was added later.
#  This line was added later.
#  This line was added later.

# %%
import json
data = {"owner": "Ram","balance":2500}
json_string = json.dumps(data)
print(json_string)

back_to_dict = json.loads(json_string)
print(back_to_dict["owner"])
# Out:
# {"owner": "Ram", "balance": 2500}
# Ram

# %%
import json

data = {"owner": "Ram","balance":2500}

with open("account.json","w") as f:
  json.dump(data, f ,indent=4)

# %%
import json

with open("account.json","r") as f:
  data = json.load(f)

print(data["owner"])
print(data["balance"])
# Out:
# Ram
# 2500

# %%
try:
  with open("account.json","r") as f:
    data = json.load(f)
except FileNotFoundError:
  print("No saved data found. Starting fresh")
  data = {}
